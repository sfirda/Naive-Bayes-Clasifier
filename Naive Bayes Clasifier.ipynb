# %%
import numpy as np
import pandas as pd

# %%
iris=pd.read_csv("iris.csv")
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width           class
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width        class
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %%
from sklearn import tree
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

# %%
X=iris.values[:,0:4]
Y=iris.values[:,4]

# %%
X_train,X_test,y_train,y_test=train_test_split(X,Y,test_size=0.2)

# %%
X_train
# Out:
# array([[4.3, 3.0, 1.1, 0.1],
#        [5.0, 2.0, 3.5, 1.0],
#        [6.4, 3.1, 5.5, 1.8],
#        [6.7, 3.1, 5.6, 2.4],
#        [7.2, 3.6, 6.1, 2.5],
#        [7.7, 3.0, 6.1, 2.3],
#        [6.3, 2.5, 5.0, 1.9],
#        [6.6, 3.0, 4.4, 1.4],
#        [6.4, 3.2, 4.5, 1.5],
#        [5.0, 3.2, 1.2, 0.2],
#        [6.4, 3.2, 5.3, 2.3],
#        [5.1, 3.5, 1.4, 0.3],
#        [6.7, 2.5, 5.8, 1.8],
#        [5.3, 3.7, 1.5, 0.2],
#        [6.0, 3.4, 4.5, 1.6],
#        [7.2, 3.0, 5.8, 1.6],
#        [5.5, 4.2, 1.4, 0.2],
#        [5.4, 3.4, 1.7, 0.2],
#        [5.8, 2.8, 5.1, 2.4],
#        [6.7, 3.0, 5.2, 2.3],
#        [5.1, 3.3, 1.7, 0.5],
#        [4.9, 3.1, 1.5, 0.1],
#        [5.2, 3.5, 1.5, 0.2],
#        [5.1, 3.7, 1.5, 0.4],
#        [5.1, 3.4, 1.5, 0.2],
#        [7.1, 3.0, 5.9, 2.1],
#        [4.9, 3.1, 1.5, 0.1],
#        [5.6, 2.5, 3.9, 1.1],
#        [6.4, 2.8, 5.6, 2.1],
#        [5.7, 2.5, 5.0, 2.0],
#        [6.1, 2.8, 4.0, 1.3],
#        [4.8, 3.0, 1.4, 0.3],
# ...

# %%
X_test
# Out:
# array([[6.1, 3.0, 4.6, 1.4],
#        [6.4, 2.9, 4.3, 1.3],
#        [5.0, 3.6, 1.4, 0.2],
#        [4.8, 3.4, 1.6, 0.2],
#        [5.8, 2.7, 5.1, 1.9],
#        [6.3, 3.3, 4.7, 1.6],
#        [5.1, 3.8, 1.5, 0.3],
#        [7.7, 3.8, 6.7, 2.2],
#        [5.8, 2.7, 4.1, 1.0],
#        [6.3, 2.7, 4.9, 1.8],
#        [6.9, 3.1, 4.9, 1.5],
#        [5.1, 3.8, 1.6, 0.2],
#        [6.2, 2.9, 4.3, 1.3],
#        [6.3, 2.3, 4.4, 1.3],
#        [5.0, 3.5, 1.3, 0.3],
#        [5.5, 2.4, 3.8, 1.1],
#        [6.5, 3.0, 5.2, 2.0],
#        [6.7, 3.3, 5.7, 2.1],
#        [4.4, 3.0, 1.3, 0.2],
#        [4.4, 3.2, 1.3, 0.2],
#        [5.9, 3.0, 5.1, 1.8],
#        [5.6, 2.8, 4.9, 2.0],
#        [5.6, 2.9, 3.6, 1.3],
#        [7.7, 2.6, 6.9, 2.3],
#        [4.8, 3.4, 1.9, 0.2],
#        [5.7, 2.6, 3.5, 1.0],
#        [7.9, 3.8, 6.4, 2.0],
#        [6.2, 3.4, 5.4, 2.3],
#        [6.1, 2.9, 4.7, 1.4],
#        [6.9, 3.1, 5.1, 2.3]], dtype=object)

# %%
a=pd.DataFrame(X_test)
a
# Out:
#       0    1    2    3
# 0   6.1  3.0  4.6  1.4
# 1   6.4  2.9  4.3  1.3
# 2   5.0  3.6  1.4  0.2
# 3   4.8  3.4  1.6  0.2
# 4   5.8  2.7  5.1  1.9
# 5   6.3  3.3  4.7  1.6
# 6   5.1  3.8  1.5  0.3
# 7   7.7  3.8  6.7  2.2
# 8   5.8  2.7  4.1  1.0
# 9   6.3  2.7  4.9  1.8
# 10  6.9  3.1  4.9  1.5
# 11  5.1  3.8  1.6  0.2
# 12  6.2  2.9  4.3  1.3
# 13  6.3  2.3  4.4  1.3
# 14  5.0  3.5  1.3  0.3
# 15  5.5  2.4  3.8  1.1
# 16  6.5  3.0  5.2  2.0
# 17  6.7  3.3  5.7  2.1
# 18  4.4  3.0  1.3  0.2
# 19  4.4  3.2  1.3  0.2
# 20  5.9  3.0  5.1  1.8
# 21  5.6  2.8  4.9  2.0
# 22  5.6  2.9  3.6  1.3
# 23  7.7  2.6  6.9  2.3
# 24  4.8  3.4  1.9  0.2
# 25  5.7  2.6  3.5  1.0
# 26  7.9  3.8  6.4  2.0
# 27  6.2  3.4  5.4  2.3
# 28  6.1  2.9  4.7  1.4
# 29  6.9  3.1  5.1  2.3

# %%
clf_gini=tree.DecisionTreeClassifier(criterion="gini",max_depth=None,min_samples_leaf=2)
clf_gini=clf_gini.fit(X_train,y_train)

# %%
clf_entropy=tree.DecisionTreeClassifier(criterion="entropy",max_depth=None,min_samples_leaf=2)
clf_entropy=clf_entropy.fit(X_train,y_train)

# %%
y_pred_gini=clf_gini.predict(X_test)
y_pred_gini
# Out:
# array(['Iris-versicolor', 'Iris-versicolor', 'Iris-setosa', 'Iris-setosa',
#        'Iris-virginica', 'Iris-versicolor', 'Iris-setosa',
#        'Iris-virginica', 'Iris-versicolor', 'Iris-virginica',
#        'Iris-versicolor', 'Iris-setosa', 'Iris-versicolor',
#        'Iris-versicolor', 'Iris-setosa', 'Iris-versicolor',
#        'Iris-virginica', 'Iris-virginica', 'Iris-setosa', 'Iris-setosa',
#        'Iris-virginica', 'Iris-virginica', 'Iris-versicolor',
#        'Iris-virginica', 'Iris-setosa', 'Iris-versicolor',
#        'Iris-virginica', 'Iris-virginica', 'Iris-versicolor',
#        'Iris-virginica'], dtype=object)

# %%
y_pred_info=clf_entropy.predict(X_test)
y_pred_info
# Out:
# array(['Iris-versicolor', 'Iris-versicolor', 'Iris-setosa', 'Iris-setosa',
#        'Iris-virginica', 'Iris-versicolor', 'Iris-setosa',
#        'Iris-virginica', 'Iris-versicolor', 'Iris-versicolor',
#        'Iris-versicolor', 'Iris-setosa', 'Iris-versicolor',
#        'Iris-versicolor', 'Iris-setosa', 'Iris-versicolor',
#        'Iris-virginica', 'Iris-virginica', 'Iris-setosa', 'Iris-setosa',
#        'Iris-versicolor', 'Iris-virginica', 'Iris-versicolor',
#        'Iris-virginica', 'Iris-setosa', 'Iris-versicolor',
#        'Iris-virginica', 'Iris-virginica', 'Iris-versicolor',
#        'Iris-virginica'], dtype=object)

# %%
accuracy_score(y_test,y_pred_gini)*100
# Out:
# 100.0

# %%
accuracy_score(y_test,y_pred_info)*100
# Out:
# 93.33333333333333

# %%
iris_pred_gini=pd.DataFrame(y_pred_gini)
iris_pred_gini.to_csv("iris_pred_gini.csv")
iris_pred_info=pd.DataFrame(y_pred_info)
iris_pred_info.to_csv("iris_pred_info.csv")

# %%
ftrs=['sepal length','sepal width','petal length','petal width']
cls=['viginica','sentosa','versicolor']
import matplotlib.pyplot as plt
fig, axes=plt.subplots(nrows=1,ncols=1,figsize=(4,4),dpi=300)
tree.plot_tree(clf_gini,feature_names=ftrs,
               class_names=cls,filled=True)
fig.savefig('iristregini.png')

# %%
ftrs=['sepal length','sepal width','petal length','petal width']
cls=['viginica','sentosa','versicolor']
import matplotlib.pyplot as plt
fig, axes=plt.subplots(nrows=1,ncols=1,figsize=(4,4),dpi=300)
tree.plot_tree(clf_entropy,feature_names=ftrs,
               class_names=cls,filled=True)
fig.savefig('iristreeinfo.png')
